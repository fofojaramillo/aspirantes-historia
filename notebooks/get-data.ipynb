# %%
import pandas as pd
import numpy as np
import regex as re

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# # Transformación de los Datos...

# %%
aspirantes_mcd = pd.DataFrame()

for year in range(2020,2024):
    df = pd.read_excel(f'..\\data\\aspirantes_{year}.xlsx')
    
    aspirantes_mcd = pd.concat([aspirantes_mcd,df])

aspirantes_mcd
# Out:
#     Fecha Nacimiento    Pais     Estado    Sexo   Estado Civil  Num Hijos  \
# 0    23/12/1989 (33)  MÉXICO     SONORA   MUJER      CASADO(A)          0
# 1    23/12/1989 (33)  MÉXICO     SONORA   MUJER      CASADO(A)          0
# 2    14/09/1970 (53)  MÉXICO  CHIHUAHUA  HOMBRE  DIVORCIADO(A)          1
# 3    12/04/1985 (38)  MÉXICO     SONORA  HOMBRE      CASADO(A)          1
# 4    06/01/1991 (32)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# ..               ...     ...        ...     ...            ...        ...
# 96   20/07/2000 (23)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 97   06/04/1999 (24)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 98   14/10/1995 (28)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 99   14/10/1995 (28)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 100  17/04/2000 (23)  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
#
#                                  Religión             Estatus Proceso  \
# ...

# %%
date_birth = list(aspirantes_mcd['Fecha Nacimiento'])

# %%
age = []
for date in date_birth:
    age.append(int(date[-3:-1]))

# %%
aspirantes_mcd['Edad'] = age

aspirantes_mcd=aspirantes_mcd.drop(columns='Fecha Nacimiento')

# %%
status = list(aspirantes_mcd['Estatus Proceso'])

aceptado = [True if stat == '[7] ACEPTADO' else False for stat in status]

aspirantes_mcd['Aceptado'] = aceptado

aspirantes_mcd = aspirantes_mcd.drop(columns='Estatus Proceso')

# %%
nacional = list(aspirantes_mcd['Nacionalidad'])

nacional = [True if x == 'MEXICANO' else False for x in nacional]

aspirantes_mcd['Nacionalidad'] = nacional

# %%
aspirantes_mcd
# Out:
#        Pais     Estado    Sexo   Estado Civil  Num Hijos  \
# 0    MÉXICO     SONORA   MUJER      CASADO(A)          0
# 1    MÉXICO     SONORA   MUJER      CASADO(A)          0
# 2    MÉXICO  CHIHUAHUA  HOMBRE  DIVORCIADO(A)          1
# 3    MÉXICO     SONORA  HOMBRE      CASADO(A)          1
# 4    MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# ..      ...        ...     ...            ...        ...
# 96   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 97   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 98   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 99   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 100  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
#
#                                  Religión Fecha Pre-registro  Nacionalidad  \
# 0                        NINGUNA RELIGIÓN         05/03/2020          True
# 1                        NINGUNA RELIGIÓN         05/03/2020          True
# ...

# %%
aspirantes_mcd['Fecha Pre-registro'] = pd.to_datetime(aspirantes_mcd['Fecha Pre-registro'], format='%d/%m/%Y')
aspirantes_mcd['Licenciatura: Fecha Titulación'] = pd.to_datetime(aspirantes_mcd['Licenciatura: Fecha Titulación'], format='%d/%m/%Y')

# %%
aspirantes_mcd['Experiencia'] = aspirantes_mcd['Fecha Pre-registro'].dt.year-aspirantes_mcd['Licenciatura: Fecha Titulación'].dt.year

# %%
aspirantes_mcd['Experiencia']
# Out:
# 0       8.0
# 1       0.0
# 2      27.0
# 3       NaN
# 4       2.0
#        ...
# 96      0.0
# 97      NaN
# 98      5.0
# 99      0.0
# 100     NaN
# Name: Experiencia, Length: 240, dtype: float64

# %%
aspirantes_mcd
# Out:
#        Pais     Estado    Sexo   Estado Civil  Num Hijos  \
# 0    MÉXICO     SONORA   MUJER      CASADO(A)          0
# 1    MÉXICO     SONORA   MUJER      CASADO(A)          0
# 2    MÉXICO  CHIHUAHUA  HOMBRE  DIVORCIADO(A)          1
# 3    MÉXICO     SONORA  HOMBRE      CASADO(A)          1
# 4    MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# ..      ...        ...     ...            ...        ...
# 96   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 97   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 98   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 99   MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
# 100  MÉXICO     SONORA  HOMBRE     SOLTERO(A)          0
#
#                                  Religión Fecha Pre-registro  Nacionalidad  \
# 0                        NINGUNA RELIGIÓN         2020-03-05          True
# 1                        NINGUNA RELIGIÓN         2020-03-05          True
# ...

# %%
#Eliminando columnas
aspirantes_mcd = aspirantes_mcd.drop(columns = ['Religión', 'Num Hijos', 'Pais', 'Estado', 'Fecha Pre-registro', 'Licenciatura: Fecha Titulación', 'aspirantePosgradoId'])

# %%
aspirantes_mcd
# Out:
#        Sexo   Estado Civil  Nacionalidad            Licenciatura: Institución  \
# 0     MUJER      CASADO(A)          True        UNIVERSIDAD ESTATAL DE SONORA
# 1     MUJER      CASADO(A)          True                UNIVERSIDAD DE SONORA
# 2    HOMBRE  DIVORCIADO(A)          True   INSTITUTO TECNOLÓGICO DE CHIHUAHUA
# 3    HOMBRE      CASADO(A)          True                UNIVERSIDAD DE SONORA
# 4    HOMBRE     SOLTERO(A)          True      UNIVERSIDAD DEL VALLE DE MÉXICO
# ..      ...            ...           ...                                  ...
# 96   HOMBRE     SOLTERO(A)          True  INSTITUTO TECNOLÓGICO DE HERMOSILLO
# 97   HOMBRE     SOLTERO(A)          True                UNIVERSIDAD DE SONORA
# 98   HOMBRE     SOLTERO(A)          True                               UNISON
# 99   HOMBRE     SOLTERO(A)          True                               UNISON
# 100  HOMBRE     SOLTERO(A)          True                               UNISON
#
# ...

# %%
aspirantes_mcd = aspirantes_mcd[['Sexo','Edad','Nacionalidad','Estado Civil','Experiencia','Licenciatura: Institución','Licenciatura: Programa','Licenciatura: Promedio','Licenciatura: Tipo Titulación','Aceptado']]

# %% [markdown]
# # Chequeando la calidad de los datos antes de crear el Tidy...

# %%
# Chequeando calidad de los datos...
aspirantes_mcd.info()
aspirantes_mcd.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Sexo                           240 non-null    object
#  1   Edad                           240 non-null    int64
#  2   Nacionalidad                   240 non-null    bool
#  3   Estado Civil                   240 non-null    object
#  4   Experiencia                    204 non-null    float64
#  5   Licenciatura: Institución      237 non-null    object
#  6   Licenciatura: Programa         237 non-null    object
#  7   Licenciatura: Promedio         240 non-null    float64
#  8   Licenciatura: Tipo Titulación  237 non-null    object
#  9   Aceptado                       240 non-null    bool
# dtypes: bool(2), float64(2), int64(1), object(5)
# memory usage: 17.3+ KB
# (240, 10)

# %%
# Total de nulos... por columnas...
aspirantes_mcd.isnull().sum()
# Out:
# Sexo                              0
# Edad                              0
# Nacionalidad                      0
# Estado Civil                      0
# Experiencia                      36
# Licenciatura: Institución         3
# Licenciatura: Programa            3
# Licenciatura: Promedio            0
# Licenciatura: Tipo Titulación     3
# Aceptado                          0
# dtype: int64

# %%
# Encontrar filas con valores nulos para cada columna
filas_con_nulos = aspirantes_mcd.isnull().any(axis=1)

# Imprimir las filas con valores nulos
print("Filas con valores nulos:")
print(aspirantes_mcd[filas_con_nulos])
# Out:
# Filas con valores nulos:
#        Sexo  Edad  Nacionalidad Estado Civil  Experiencia  \
# 3    HOMBRE    38          True    CASADO(A)          NaN
# 14   HOMBRE    42          True    CASADO(A)          NaN
# 15   HOMBRE    37          True   SOLTERO(A)          NaN
# 16   HOMBRE    51          True    CASADO(A)          NaN
# 18   HOMBRE    28          True   SOLTERO(A)          NaN
# 25   HOMBRE    27          True   SOLTERO(A)          NaN
# 28   HOMBRE    35          True    CASADO(A)          NaN
# 15    MUJER    33          True   SOLTERO(A)          NaN
# 20   HOMBRE    39          True    CASADO(A)          NaN
# 23   HOMBRE    37          True    CASADO(A)          NaN
# 34    MUJER    25          True   SOLTERO(A)          NaN
# 38    MUJER    25          True   SOLTERO(A)          NaN
# 3    HOMBRE    29         False   SOLTERO(A)          NaN
# 24   HOMBRE    23          True   SOLTERO(A)          NaN
# 26   HOMBRE    30          True   SOLTERO(A)          NaN
# ...

# %%
# Se van a impotar a "0" los valores nulos de la columna experiencia... Y "Desconocida/o" en caso que las (Instituciones, Programa y Título) estén vacías...
aspirantes_mcd["Experiencia"] = aspirantes_mcd["Experiencia"].fillna(0, inplace=True)
aspirantes_mcd["Licenciatura: Institución"] = aspirantes_mcd["Licenciatura: Institución"].fillna("Desconocida", inplace=True)
aspirantes_mcd["Licenciatura: Programa"] = aspirantes_mcd["Licenciatura: Programa"].fillna("Desconocido", inplace=True)
aspirantes_mcd["Licenciatura: Tipo Titulación"] = aspirantes_mcd["Licenciatura: Tipo Titulación"].fillna("Desconocido", inplace=True)

# Verificando que no hay valores nulos...
aspirantes_mcd.isnull().sum()
# Out:
# Sexo                               0
# Edad                               0
# Nacionalidad                       0
# Estado Civil                       0
# Experiencia                      240
# Licenciatura: Institución        240
# Licenciatura: Programa           240
# Licenciatura: Promedio             0
# Licenciatura: Tipo Titulación    240
# Aceptado                           0
# dtype: int64

# %% [markdown]
# # Exportando el Tidy...

# %%
aspirantes_mcd.to_excel('aspirantes-mcd_tidy.xlsx', index=False)
